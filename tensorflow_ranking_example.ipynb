# %%
from typing import Dict, Tuple

import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       1 from typing import Dict, Tuple
#       3 import tensorflow as tf
# ----> 5 import tensorflow_datasets as tfds
#       6 import tensorflow_ranking as tfr
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\__init__.py:41
#      39 import time
#      40 _TIMESTAMP_IMPORT_STARTS = time.time()
# ---> 41 import tensorflow_datasets.core.logging as _tfds_logging
#      42 from tensorflow_datasets.core.logging import call_metadata as _call_metadata
#      44 _metadata = _call_metadata.CallMetadata()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\__init__.py:33
#      30 from etils.epath import Path
#      31 # pylint: enable=g-bad-import-order
# ---> 33 from tensorflow_datasets.core import community  # pylint: disable=g-bad-import-order
#      34 from tensorflow_datasets.core.dataset_builder import BeamBasedBuilder
#      35 from tensorflow_datasets.core.dataset_builder import BuilderConfig
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\community\__init__.py:18
#       1 # coding=utf-8
#       2 # Copyright 2022 The TensorFlow Datasets Authors.
#       3 #
#    (...)
#      13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
#      16 """Community dataset API."""
# ---> 18 from tensorflow_datasets.core.community.huggingface_wrapper import mock_builtin_to_use_gfile
#      19 from tensorflow_datasets.core.community.huggingface_wrapper import mock_huggingface_import
#      20 from tensorflow_datasets.core.community.load import builder_cls_from_module
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\community\huggingface_wrapper.py:30
#      28 from etils import epath
#      29 import tensorflow as tf
# ---> 30 from tensorflow_datasets.core import dataset_builder
#      31 from tensorflow_datasets.core import dataset_info
#      32 from tensorflow_datasets.core import download
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\dataset_builder.py:34
#      32 import six
#      33 import tensorflow as tf
# ---> 34 from tensorflow_datasets.core import dataset_info
#      35 from tensorflow_datasets.core import decode
#      36 from tensorflow_datasets.core import download
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\dataset_info.py:46
#      43 import six
#      44 import tensorflow as tf
# ---> 46 from tensorflow_datasets.core import file_adapters
#      47 from tensorflow_datasets.core import lazy_imports_lib
#      48 from tensorflow_datasets.core import naming
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\file_adapters.py:25
#      23 from etils import epath
#      24 import tensorflow as tf
# ---> 25 from tensorflow_datasets.core.utils import type_utils
#      27 ExamplePositions = List[Any]
#      30 class FileFormat(enum.Enum):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\utils\__init__.py:20
#      18 # pylint: disable=wildcard-import
#      19 from tensorflow_datasets.core.units import Size
# ---> 20 from tensorflow_datasets.core.utils import docs
#      21 from tensorflow_datasets.core.utils import tree_utils as tree
#      22 from tensorflow_datasets.core.utils.gcs_utils import gcs_path
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\utils\docs.py:33
#       1 # coding=utf-8
#       2 # Copyright 2022 The TensorFlow Datasets Authors.
#       3 #
#    (...)
#      13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
#      16 """Documentation utils for the website.
#      17
#      18 Note: To be detected, doc decorators should be applied between descriptors
#    (...)
#      30
#      31 """
# ---> 33 from tensorflow.tools.docs import doc_controls  # pylint: disable=g-direct-tensorflow-import
#      36 def _no_op_decorator(obj):
#      37   return obj
#
# ModuleNotFoundError: No module named 'tensorflow.tools'

# %%
import tensorflow_datasets as tfds
import tensorflow_ranking as tfr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import tensorflow_datasets as tfds
#       2 import tensorflow_ranking as tfr
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\__init__.py:41
#      39 import time
#      40 _TIMESTAMP_IMPORT_STARTS = time.time()
# ---> 41 import tensorflow_datasets.core.logging as _tfds_logging
#      42 from tensorflow_datasets.core.logging import call_metadata as _call_metadata
#      44 _metadata = _call_metadata.CallMetadata()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\__init__.py:33
#      30 from etils.epath import Path
#      31 # pylint: enable=g-bad-import-order
# ---> 33 from tensorflow_datasets.core import community  # pylint: disable=g-bad-import-order
#      34 from tensorflow_datasets.core.dataset_builder import BeamBasedBuilder
#      35 from tensorflow_datasets.core.dataset_builder import BuilderConfig
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\community\__init__.py:18
#       1 # coding=utf-8
#       2 # Copyright 2022 The TensorFlow Datasets Authors.
#       3 #
#    (...)
#      13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
#      16 """Community dataset API."""
# ---> 18 from tensorflow_datasets.core.community.huggingface_wrapper import mock_builtin_to_use_gfile
#      19 from tensorflow_datasets.core.community.huggingface_wrapper import mock_huggingface_import
#      20 from tensorflow_datasets.core.community.load import builder_cls_from_module
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\community\huggingface_wrapper.py:30
#      28 from etils import epath
#      29 import tensorflow as tf
# ---> 30 from tensorflow_datasets.core import dataset_builder
#      31 from tensorflow_datasets.core import dataset_info
#      32 from tensorflow_datasets.core import download
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\dataset_builder.py:34
#      32 import six
#      33 import tensorflow as tf
# ---> 34 from tensorflow_datasets.core import dataset_info
#      35 from tensorflow_datasets.core import decode
#      36 from tensorflow_datasets.core import download
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\dataset_info.py:46
#      43 import six
#      44 import tensorflow as tf
# ---> 46 from tensorflow_datasets.core import file_adapters
#      47 from tensorflow_datasets.core import lazy_imports_lib
#      48 from tensorflow_datasets.core import naming
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\file_adapters.py:25
#      23 from etils import epath
#      24 import tensorflow as tf
# ---> 25 from tensorflow_datasets.core.utils import type_utils
#      27 ExamplePositions = List[Any]
#      30 class FileFormat(enum.Enum):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\utils\__init__.py:20
#      18 # pylint: disable=wildcard-import
#      19 from tensorflow_datasets.core.units import Size
# ---> 20 from tensorflow_datasets.core.utils import docs
#      21 from tensorflow_datasets.core.utils import tree_utils as tree
#      22 from tensorflow_datasets.core.utils.gcs_utils import gcs_path
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_datasets\core\utils\docs.py:33
#       1 # coding=utf-8
#       2 # Copyright 2022 The TensorFlow Datasets Authors.
#       3 #
#    (...)
#      13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
#      16 """Documentation utils for the website.
#      17
#      18 Note: To be detected, doc decorators should be applied between descriptors
#    (...)
#      30
#      31 """
# ---> 33 from tensorflow.tools.docs import doc_controls  # pylint: disable=g-direct-tensorflow-import
#      36 def _no_op_decorator(obj):
#      37   return obj
#
# ModuleNotFoundError: No module named 'tensorflow.tools'

# %%
tfr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tfr
#
# NameError: name 'tfr' is not defined
